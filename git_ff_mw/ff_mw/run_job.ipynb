# %%
from databricks.sdk.service.jobs import JobSettings
from databricks.sdk import WorkspaceClient

# %%
w = WorkspaceClient()

# %%
run = w.jobs.run_now(
    job_id=125027377557102
)

# %%
# run = w.jobs.run_now(
#     job_id=238563918452880
# )
